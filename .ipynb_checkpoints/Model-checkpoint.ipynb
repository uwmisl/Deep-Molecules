# %%
import torch
from torch import optim
import torch.nn as nn
import torch.nn.functional as F
import torch.autograd as autograd
from torch.autograd import Variable

import pandas as pd
from itertools import groupby
import collections
from sklearn.preprocessing import OneHotEncoder
import os, math, glob, argparse
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import numpy as np

# %%
cuda = True if torch.cuda.is_available() else False

# %% [markdown]
# ## Utitilites

# %%
def _sample_gumbel(shape, eps=1e-20, out=None):
    """
    Sample from Gumbel(0, 1)
    based on
    https://github.com/ericjang/gumbel-softmax/blob/3c8584924603869e90ca74ac20a6a03d99a91ef9/Categorical%20VAE.ipynb ,
    (MIT license)
    """
    U = out.resize_(shape).uniform_() if out is not None else torch.rand(shape)
    return - torch.log(eps - torch.log(U + eps))


def _gumbel_softmax_sample(logits, temp=1, eps=1e-20):
    """
    Draw a sample from the Gumbel-Softmax distribution
    based on
    https://github.com/ericjang/gumbel-softmax/blob/3c8584924603869e90ca74ac20a6a03d99a91ef9/Categorical%20VAE.ipynb
    (MIT license)
    """
    dims = logits.dim()
    gumbel_noise = _sample_gumbel(logits.size(), eps=eps, out=logits.data.new())
    y = logits + Variable(gumbel_noise)
    return F.softmax(y / temp, dims - 1)


def gumbel_softmax(logits, temp=1, hard=False, eps=1e-20):
    """
    Sample from the Gumbel-Softmax distribution and optionally discretize.
    Args:
      logits: [batch_size, n_class] unnormalized log-probs
      temp: non-negative scalar temperature
      hard: if True, take argmax, but differentiate w.r.t. soft sample y
    Returns:
      [batch_size, n_class] sample from the Gumbel-Softmax distribution.
      If hard=True, then the returned sample will be one-hot, otherwise it will
      be a probability distribution that sums to 1 across classes
    Constraints: - this implementation only works on batch_size x num_features tensor for now
    based on
    https://github.com/ericjang/gumbel-softmax/blob/3c8584924603869e90ca74ac20a6a03d99a91ef9/Categorical%20VAE.ipynb ,
    (MIT license)
    """
    shape = logits.size()
    assert len(shape) == 2
    y_soft = _gumbel_softmax_sample(logits, temp=temp, eps=eps)
    if not hard:
        return y_soft
    _, k = y_soft.data.max(-1)
    y_hard = logits.data.new(*shape).zero_().scatter_(-1, k.view(-1, 1), 1.0)
    return Variable(y_hard - y_soft.data) + y_soft

def load_dataset(max_length, max_n_examples, max_vocab_size=2048, data_dir=''):
    print ("loading dataset...")
    data = pd.read_csv(data_dir)
    dirname = data_dir.split('.')
    dirfilename = (dirname[1].split('/'))[-1]
    print(dirfilename)
    lines = list(set(data['SEQUENCE'].tolist()))
    make_graphs(lines, dirfilename)
    lines = [l for l in lines if ('X' not in l)]
    make_graphs(lines, dirfilename + '_no_X')
    
    
    
    lines = [l for l in lines if (len(l) <= max_length)]
    lines = [tuple(l + '0'*(max_length - len(l))) for l in lines] # pad with 0
    print("loaded {} lines in dataset".format(len(lines)))    
    
    np.random.shuffle(lines)
    counts = collections.Counter(char for line in lines for char in line)

    charmap = {}
    inv_charmap = []

    for char,count in counts.most_common(max_vocab_size-1):
        if char not in charmap:
            charmap[char] = len(inv_charmap)
            inv_charmap.append(char)
            
    return lines, charmap, inv_charmap

def to_var(x):
    if torch.cuda.is_available():
        x = x.cuda()
    return Variable(x)

def decode_one_seq(img, letter_dict):
    seq = ''
    for row in range(len(img)):
        on = np.argmax(img[row,:])
        seq += letter_dict[on]
    return seq

def make_graphs(lines, name):
    lines = [s.replace('0', '') for s in lines]
    # Make graph -- length
    lengths = [len(s) for s in lines]
    count_lengths = collections.Counter(lengths)
    fig, ax = plt.subplots(3, figsize=(15,30))
    ax[0].bar(count_lengths.keys(), count_lengths.values())
    ax[0].grid()
    ax[0].set_title('Frequency of Sequence Lengths')
    ax[0].set_xlabel('Length')
    ax[0].set_ylabel('Frequency')
    ax[1].bar(count_lengths.keys(), count_lengths.values())
    ax[1].grid()
    ax[1].set_title('Frequency of Sequence Lengths')
    ax[1].set_xlabel('Length')
    ax[1].set_ylabel('Frequency')
    ax[1].set_xlim((0, 1000))
    ax[2].bar(count_lengths.keys(), count_lengths.values())
    ax[2].grid()
    ax[2].set_title('Frequency of Sequence Lengths')
    ax[2].set_xlabel('Length')
    ax[2].set_ylabel('Frequency')
    ax[2].set_xlim((0, 600))
    fig.savefig('./graphs/{0}_Seq_Lengths.png'.format(name))
    # Make graph -- freq
    freq = {}
    for s in lines:
      for k, v in collections.Counter(s).items():
          if k not in freq:
            freq[k] = 0
          freq[k] += v
    fig, ax = plt.subplots(1, figsize=(15,10))
    ofreq = collections.OrderedDict(sorted(freq.items()))
    ax.bar(ofreq.keys(), ofreq.values())
    ax.grid()
    ax.set_title('Frequency of Amino Acids')
    ax.set_xlabel('Amino Acids')
    ax.set_ylabel('Frequency')
    fig.savefig('./graphs/{0}_Seq_Freq.png'.format(name))
    # Make graph -- dups
    dups = {}
    for s in lines:
      for k, v in collections.Counter(zip(s, s[1:])).items():
        if k[0] == k[1]:
          if k[0] not in dups:
            dups[k[0]] = 0
          dups[k[0]] += v
    fig, ax = plt.subplots(1, figsize=(15,10))
    odups = collections.OrderedDict(sorted(dups.items()))
    ax.bar(odups.keys(), odups.values())
    ax.grid()
    ax.set_title('Frequency of Duplicate Amino Acids')
    ax.set_xlabel('Amino Acids')
    ax.set_ylabel('Frequency')
    fig.savefig('./graphs/{0}_Seq_Dups.png'.format(name))
    # Make graph -- runs
    runs = np.zeros(2000)
    for s in lines:
        ch = s[0]
        count = 1
        for i in range(1, len(s)):
            if s[i] == ch:
                count += 1
            else:
                runs[count] += 1
                ch = s[i]
                count = 1
    runs = runs / len(lines)
            
    fig, ax = plt.subplots(1, figsize=(15,10))
    odups = collections.OrderedDict(sorted(dups.items()))
    ax.bar(np.arange(0, 2000), runs)
    ax.grid()
    ax.set_title('Frequency of Runs Lengths')
    ax.set_xlabel('Run Length')
    ax.set_ylabel('log(Frequency)')
    ax.set_yscale("log")
    fig.savefig('./graphs/{0}_Seq_Runs.png'.format(name))
    plt.close('all')

# %% [markdown]
# ## FBGAN

# %%
class Generator(nn.Module):
    def __init__(self, seq_len, batch_size, dim, num_classes):
        super(Generator, self).__init__()

        def block(dim):
            layers = []
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            return layers
        
        self.L = nn.Linear(128, dim*seq_len)
        self.C = nn.Conv1d(dim, num_classes, 1)
        self.model = nn.Sequential(
            *block(dim),
            *block(dim),
            *block(dim),
            *block(dim),
            *block(dim),
            *block(dim),
            *block(dim),
            *block(dim),
            *block(dim),
            *block(dim)
        )
        self.seq_len = seq_len
        self.batch_size = batch_size
        self.dim = dim;
        self.num_classes = num_classes;

    def forward(self, z):
        out = self.L(z) # (batch_size, dim * seq_len)
        out = out.view(-1, self.dim, self.seq_len) # (batch_size, dim, seq_len)
        out = self.model(out)
        out = self.C(out) # (batch_size, num_classes, seq_len)
        out = out.transpose(1, 2)
        size = out.size()
        out = out.contiguous()
        out = out.view(self.batch_size*self.seq_len, -1)
        out = gumbel_softmax(out, 0.5)
        return out.view(size)

# %%
class Discriminator(nn.Module):
    def __init__(self, seq_len, batch_size, dim, num_classes):
        super(Discriminator, self).__init__()
        
        def block(dim):
            layers = []
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(dim, dim, 5, padding=2))
            layers.append(nn.ReLU(inplace=True))
            return layers
        
        self.C = nn.Conv1d(num_classes, dim, 1)
        
        self.model = nn.Sequential(
            *block(dim),
            *block(dim),
            *block(dim),
            *block(dim)
        )
        self.seq_len = seq_len
        self.batch_size = batch_size
        self.dim = dim;
        self.num_classes = num_classes;
        self.linear = nn.Linear(seq_len*dim, 1)
        self.activation = nn.Sigmoid()

    def forward(self, input):
        out = input.transpose(1, 2)
        out = self.C(out)
        out = self.model(out)
        out = out.view(-1, self.seq_len*self.dim)
        out = self.linear(out)
        out = self.activation(out)
        return out

# %% [markdown]
# ## Train Model

# %%
class FBGAN():
    def __init__(self, batch_size=64, lr=0.00001, num_epochs=100, seq_len = 400, data_dir='./data/PDB-2021AUG02.csv', \
        run_name='test02', hidden=256, d_steps = 10):
        self.hidden = hidden
        self.batch_size = batch_size
        self.lr = lr
        self.n_epochs = num_epochs
        self.seq_len = seq_len
        self.d_steps = d_steps
        self.g_steps = 1
        self.lamda = 10
        self.sample_dir = './samples/' + run_name + "/"
        self.load_data(data_dir)
        if not os.path.exists(self.sample_dir): os.makedirs(self.sample_dir)
        self.use_cuda = True if torch.cuda.is_available() else False
        self.build_model()

    def build_model(self):
        self.G = Generator(self.seq_len, self.batch_size, self.hidden, len(self.charmap))
        self.D = Discriminator(self.seq_len, self.batch_size, self.hidden, len(self.charmap))
        if self.use_cuda:
            self.G.cuda()
            self.D.cuda()
        print(self.G)
        print(self.D)
        self.G_optimizer = optim.Adam(self.G.parameters(), lr=self.lr, betas=(0.5, 0.9))
        self.D_optimizer = optim.Adam(self.D.parameters(), lr=self.lr, betas=(0.5, 0.9))

    def load_data(self, datadir):
        max_examples = 1e6
        lines, self.charmap, self.inv_charmap = load_dataset(
            max_length=self.seq_len,
            max_n_examples=max_examples,
            data_dir=datadir
        )
        self.data = lines

    def calc_gradient_penalty(self, real_data, fake_data):
        alpha = torch.rand(self.batch_size, 1, 1)
        alpha = alpha.view(-1,1,1)
        alpha = alpha.expand_as(real_data)
        alpha = alpha.cuda() if self.use_cuda else alpha
        interpolates = alpha * real_data + ((1 - alpha) * fake_data)

        interpolates = interpolates.cuda() if self.use_cuda else interpolates
        interpolates = autograd.Variable(interpolates, requires_grad=True)

        disc_interpolates = self.D(interpolates)

        gradients = autograd.grad(outputs=disc_interpolates, inputs=interpolates,
                                  grad_outputs=torch.ones(disc_interpolates.size()).cuda() \
                                  if self.use_cuda else torch.ones(disc_interpolates.size()),
                                  create_graph=True, retain_graph=True, only_inputs=True)[0]

        gradient_penalty = ((gradients.norm(2, dim=1).norm(2,dim=1) - 1) ** 2).mean() * self.lamda
        return gradient_penalty
    
    def train_model(self):
        init_epoch = 1
        total_iterations = 4000
        d_fake_losses, d_real_losses, grad_penalties = [],[],[]
        G_losses, D_losses, W_dist = [],[],[]

        one = one = torch.tensor(1, dtype=torch.float)
        one = one.cuda() if self.use_cuda else one
        one_neg = one * -1

        table = np.arange(len(self.charmap)).reshape(-1, 1)
        one_hot = OneHotEncoder()
        one_hot.fit(table)

        i = 0
        for epoch in range(self.n_epochs):
            n_batches = int(len(self.data)/self.batch_size)
            for idx in range(n_batches):
                _data = np.array(
                    [[self.charmap[c] for c in l] for l in self.data[idx*self.batch_size:(idx+1)*self.batch_size]],
                    dtype='int32'
                )
                data_one_hot = one_hot.transform(_data.reshape(-1, 1)).toarray().reshape(self.batch_size, -1, len(self.charmap))
                real_data = torch.Tensor(data_one_hot)
                real_data = to_var(real_data)
                for p in self.D.parameters():  # reset requires_grad
                    p.requires_grad = True  # they are set to False below in netG update
                d_real_acc = 0
                d_fake_acc = 0
                for _ in range(self.d_steps):
                    self.D.zero_grad()
                    d_real_pred = self.D(real_data)
                    d_real_err = torch.mean(d_real_pred) #want to push d_real as high as possible
                    d_real_acc += d_real_err.item()
                    d_real_err.backward(one_neg)

                    z_input = to_var(torch.randn(self.batch_size, 128))
                    d_fake_data = self.G(z_input).detach()
                    d_fake_pred = self.D(d_fake_data)
                    d_fake_err = torch.mean(d_fake_pred) #want to push d_fake as low as possible
                    d_fake_acc += d_fake_err.item()
                    d_fake_err.backward(one)

                    gradient_penalty = self.calc_gradient_penalty(real_data.data, d_fake_data.data)
                    gradient_penalty.backward()

                    d_err = d_fake_err - d_real_err + gradient_penalty
                    self.D_optimizer.step()
                d_real_acc /= self.d_steps
                d_fake_acc = (d_fake_acc / self.d_steps)
                print("Accuracy on real data:", 1 - d_real_acc)
                print("Accuracy on fake data:", 1 - d_fake_acc)
                # Append things for logging
                d_fake_np, d_real_np, gp_np = (d_fake_err.data).cpu().numpy(), \
                        (d_real_err.data).cpu().numpy(), (gradient_penalty.data).cpu().numpy()
                grad_penalties.append(gp_np)
                d_real_losses.append(d_real_np)
                d_fake_losses.append(d_fake_np)
                D_losses.append(d_fake_np - d_real_np + gp_np)
                W_dist.append(d_real_np - d_fake_np)
                # Train G
                for p in self.D.parameters():
                    p.requires_grad = False  # to avoid computation

                self.G.zero_grad()
                z_input = to_var(torch.randn(self.batch_size, 128))
                g_fake_data = self.G(z_input)
                dg_fake_pred = self.D(g_fake_data)
                g_err = -torch.mean(dg_fake_pred)
                g_err.backward()
                self.G_optimizer.step()
                G_losses.append((g_err.data).cpu().numpy())
                if i % 100 == 99:
                    self.sample(i)
                    summary_str = 'Iteration [{}/{}] - loss_d: {}, loss_g: {}, w_dist: {}, grad_penalty: {}'\
                        .format(i, total_iterations, (d_err.data).cpu().numpy(),
                        (g_err.data).cpu().numpy(), ((d_real_err - d_fake_err).data).cpu().numpy(), gp_np)
                    print(summary_str)
                if i % 300 == 99:
                    self.sample(i, save_to_file=False)
                i += 1
                print("Iteration:" + str(i))
            np.random.shuffle(self.data)

    def sample(self, epoch, save_to_file=True):
        if save_to_file:
            z = to_var(torch.randn(self.batch_size, 128))
            self.G.eval()
            torch_seqs = self.G(z)
            seqs = (torch_seqs.data).cpu().numpy()
            decoded_seqs = [decode_one_seq(seq, self.inv_charmap)+"\n" for seq in seqs]
            with open(self.sample_dir + "sampled_{0:05}.txt".format(epoch), 'w+') as f:
                f.writelines(decoded_seqs)
        else:
            z = to_var(torch.randn(64, 128))
            self.G.eval()
            torch_seqs = self.G(z)
            seqs = (torch_seqs.data).cpu().numpy()
            decoded_seqs = [decode_one_seq(seq, self.inv_charmap) for seq in seqs]
            make_graphs(decoded_seqs, "sampled_{0:05}".format(epoch))
        self.G.train()

# %%
model = FBGAN()
model.train_model()
# Out:
# loading dataset...
# PDB-2021AUG02
# loaded 77932 lines in dataset
# Generator(
#   (L): Linear(in_features=128, out_features=102400, bias=True)
#   (C): Conv1d(256, 21, kernel_size=(1,), stride=(1,))
#   (model): Sequential(
#     (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (3): ReLU(inplace=True)
#     (4): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): ReLU(inplace=True)
#     (6): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (7): ReLU(inplace=True)
#     (8): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (9): ReLU(inplace=True)
#     (10): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (11): ReLU(inplace=True)
#     (12): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (13): ReLU(inplace=True)
#     (14): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (15): ReLU(inplace=True)
#     (16): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (17): ReLU(inplace=True)
#     (18): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (19): ReLU(inplace=True)
#     (20): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (21): ReLU(inplace=True)
#     (22): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (23): ReLU(inplace=True)
#     (24): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (25): ReLU(inplace=True)
#     (26): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (27): ReLU(inplace=True)
#     (28): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (29): ReLU(inplace=True)
#     (30): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (31): ReLU(inplace=True)
#     (32): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (33): ReLU(inplace=True)
#     (34): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (35): ReLU(inplace=True)
#     (36): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (37): ReLU(inplace=True)
#     (38): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (39): ReLU(inplace=True)
#     (40): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (41): ReLU(inplace=True)
#     (42): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (43): ReLU(inplace=True)
#     (44): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (45): ReLU(inplace=True)
#     (46): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (47): ReLU(inplace=True)
#     (48): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (49): ReLU(inplace=True)
#     (50): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (51): ReLU(inplace=True)
#     (52): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (53): ReLU(inplace=True)
#     (54): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (55): ReLU(inplace=True)
#     (56): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (57): ReLU(inplace=True)
#     (58): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (59): ReLU(inplace=True)
#     (60): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (61): ReLU(inplace=True)
#     (62): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (63): ReLU(inplace=True)
#     (64): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (65): ReLU(inplace=True)
#     (66): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (67): ReLU(inplace=True)
#     (68): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (69): ReLU(inplace=True)
#     (70): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (71): ReLU(inplace=True)
#     (72): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (73): ReLU(inplace=True)
#     (74): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (75): ReLU(inplace=True)
#     (76): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (77): ReLU(inplace=True)
#     (78): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (79): ReLU(inplace=True)
#     (80): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (81): ReLU(inplace=True)
#     (82): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (83): ReLU(inplace=True)
#     (84): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (85): ReLU(inplace=True)
#     (86): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (87): ReLU(inplace=True)
#     (88): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (89): ReLU(inplace=True)
#     (90): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (91): ReLU(inplace=True)
#     (92): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (93): ReLU(inplace=True)
#     (94): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (95): ReLU(inplace=True)
#     (96): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (97): ReLU(inplace=True)
#     (98): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (99): ReLU(inplace=True)
#   )
# )
# Discriminator(
#   (C): Conv1d(21, 256, kernel_size=(1,), stride=(1,))
#   (model): Sequential(
#     (0): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): ReLU(inplace=True)
#     (2): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (3): ReLU(inplace=True)
#     (4): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): ReLU(inplace=True)
#     (6): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (7): ReLU(inplace=True)
#     (8): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (9): ReLU(inplace=True)
#     (10): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (11): ReLU(inplace=True)
#     (12): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (13): ReLU(inplace=True)
#     (14): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (15): ReLU(inplace=True)
#     (16): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (17): ReLU(inplace=True)
#     (18): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (19): ReLU(inplace=True)
#     (20): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (21): ReLU(inplace=True)
#     (22): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (23): ReLU(inplace=True)
#     (24): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (25): ReLU(inplace=True)
#     (26): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (27): ReLU(inplace=True)
#     (28): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (29): ReLU(inplace=True)
#     (30): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (31): ReLU(inplace=True)
#     (32): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (33): ReLU(inplace=True)
#     (34): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (35): ReLU(inplace=True)
#     (36): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (37): ReLU(inplace=True)
#     (38): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (39): ReLU(inplace=True)
#   )
#   (linear): Linear(in_features=102400, out_features=1, bias=True)
#   (activation): Sigmoid()
# )
# Accuracy on real data: 0.4997084379196167
# Accuracy on fake data: 0.4997084379196167
# Iteration:1
# Accuracy on real data: 0.49974105358123777
# Accuracy on fake data: 0.49974105358123777
# Iteration:2
# Accuracy on real data: 0.49978666305541997
# Accuracy on fake data: 0.49978666305541997
# Iteration:3
# Accuracy on real data: 0.4997998654842377
# Accuracy on fake data: 0.4997998654842377
# Iteration:4
# Accuracy on real data: 0.49982751607894893
# Accuracy on fake data: 0.49982751607894893
# Iteration:5
# Accuracy on real data: 0.49984663128852846
# Accuracy on fake data: 0.49984663128852846
# Iteration:6
# Accuracy on real data: 0.4999065816402435
# Accuracy on fake data: 0.49990658760070805
# Iteration:7
# Accuracy on real data: 0.49997173547744755
# Accuracy on fake data: 0.49997174739837646
# Iteration:8
# Accuracy on real data: 0.500066614151001
# Accuracy on fake data: 0.500066614151001
# Iteration:9
# Accuracy on real data: 0.5001995891332627
# Accuracy on fake data: 0.5001995891332627
# Iteration:10
# Accuracy on real data: 0.5003380328416824
# Accuracy on fake data: 0.5003380477428436
# Iteration:11
# Accuracy on real data: 0.5004651218652725
# Accuracy on fake data: 0.5004651516675949
# Iteration:12
# Accuracy on real data: 0.5004866421222687
# Accuracy on fake data: 0.5004866629838943
# Iteration:13
# Accuracy on real data: 0.5004094779491425
# Accuracy on fake data: 0.5004095405340194
# Iteration:14
# Accuracy on real data: 0.5003088504076004
# Accuracy on fake data: 0.5003086924552917
# Iteration:15
# Accuracy on real data: 0.5000884056091308
# Accuracy on fake data: 0.5000958800315857
# Iteration:16
# Accuracy on real data: 0.5000210464000702
# Accuracy on fake data: 0.49999148547649386
# Iteration:17
# Accuracy on real data: 0.5007486075162888
# Accuracy on fake data: 0.49964134693145756
# Iteration:18
# Accuracy on real data: 0.5013331234455108
# Accuracy on fake data: 0.49937720298767085
# Iteration:19
# Accuracy on real data: 0.4986470818519593
# Accuracy on fake data: 0.5003218501806259
# Iteration:20
# Accuracy on real data: 0.5020596206188201
# Accuracy on fake data: 0.497753769159317
# Iteration:21
# Accuracy on real data: 0.4965743541717529
# Accuracy on fake data: 0.5009505450725555
# Iteration:22
# Accuracy on real data: 0.4970393359661103
# Accuracy on fake data: 0.499134823679924
# Iteration:23
# Accuracy on real data: 0.5028210490942001
# Accuracy on fake data: 0.4998794436454773
# Iteration:24
# Accuracy on real data: 0.5043773978948594
# Accuracy on fake data: 0.501859501004219
# Iteration:25
# Accuracy on real data: 0.5035006254911423
# Accuracy on fake data: 0.500044971704483
# Iteration:26
# Accuracy on real data: 0.507083398103714
# Accuracy on fake data: 0.5002351462841034
# Iteration:27
# Accuracy on real data: 0.4951257526874542
# Accuracy on fake data: 0.497574383020401
# Iteration:28
# Accuracy on real data: 0.5089737564325333
# Accuracy on fake data: 0.5009620606899261
# Iteration:29
# Accuracy on real data: 0.5030673503875732
# Accuracy on fake data: 0.49664408564567564
# Iteration:30
# Accuracy on real data: 0.5036118060350419
# Accuracy on fake data: 0.5016579031944275
# Iteration:31
# Accuracy on real data: 0.501607283949852
# Accuracy on fake data: 0.507382509112358
# Iteration:32
# Accuracy on real data: 0.49214153289794926
# Accuracy on fake data: 0.5091929376125336
# Iteration:33
# Accuracy on real data: 0.5020229697227478
# Accuracy on fake data: 0.5139904469251633
# Iteration:34
# Accuracy on real data: 0.4901585578918457
# Accuracy on fake data: 0.5157051414251328
# Iteration:35
# Accuracy on real data: 0.5135887354612351
# Accuracy on fake data: 0.5122929334640502
# Iteration:36
# Accuracy on real data: 0.5107441276311875
# Accuracy on fake data: 0.5056686103343964
# Iteration:37
# Accuracy on real data: 0.491811352968216
# Accuracy on fake data: 0.5172350883483887
# Iteration:38
# Accuracy on real data: 0.4893511474132538
# Accuracy on fake data: 0.5169929653406143
# Iteration:39
# Accuracy on real data: 0.5169566124677658
# Accuracy on fake data: 0.515304446220398
# Iteration:40
# Accuracy on real data: 0.5035124063491822
# Accuracy on fake data: 0.5183808445930481
# Iteration:41
# Accuracy on real data: 0.4995247155427933
# Accuracy on fake data: 0.5193717509508133
# Iteration:42
# Accuracy on real data: 0.5103958427906037
# Accuracy on fake data: 0.5252251833677292
# Iteration:43
# Accuracy on real data: 0.4860843360424042
# Accuracy on fake data: 0.5331319630146026
# Iteration:44
# Accuracy on real data: 0.5127914518117904
# Accuracy on fake data: 0.545159387588501
# Iteration:45
# Accuracy on real data: 0.5077708512544632
# Accuracy on fake data: 0.5306466788053512
# Iteration:46
# Accuracy on real data: 0.5011616140604019
# Accuracy on fake data: 0.5350549191236496
# Iteration:47
# Accuracy on real data: 0.4939403772354126
# Accuracy on fake data: 0.5290655225515366
# Iteration:48
# Accuracy on real data: 0.4850428223609924
# Accuracy on fake data: 0.5423182964324951
# Iteration:49
# Accuracy on real data: 0.4990161776542663
# Accuracy on fake data: 0.5362041532993317
# Iteration:50
# Accuracy on real data: 0.4659401655197144
# Accuracy on fake data: 0.5386586636304855
# Iteration:51
# Accuracy on real data: 0.5144509375095367
# Accuracy on fake data: 0.5410733193159103
# Iteration:52
# Accuracy on real data: 0.4597050189971924
# Accuracy on fake data: 0.5323992043733596
# Iteration:53
# Accuracy on real data: 0.497179639339447
# Accuracy on fake data: 0.5436303794384003
# Iteration:54
# Accuracy on real data: 0.458546781539917
# Accuracy on fake data: 0.5227533251047134
# Iteration:55
# Accuracy on real data: 0.4600617289543152
# Accuracy on fake data: 0.5286598861217499
# Iteration:56
# Accuracy on real data: 0.4632858216762543
# Accuracy on fake data: 0.5453430503606796
# Iteration:57
# Accuracy on real data: 0.48157873153686526
# Accuracy on fake data: 0.532117274403572
# Iteration:58
# Accuracy on real data: 0.4200915575027466
# Accuracy on fake data: 0.5406567394733429
# Iteration:59
# Accuracy on real data: 0.4297763466835022
# Accuracy on fake data: 0.5389519512653351
# Iteration:60
# Accuracy on real data: 0.4484579682350158
# Accuracy on fake data: 0.5402316093444824
# Iteration:61
# Accuracy on real data: 0.43508548140525816
# Accuracy on fake data: 0.5457639873027802
# Iteration:62
# Accuracy on real data: 0.4215387880802155
# Accuracy on fake data: 0.5468956023454666
# Iteration:63
# Accuracy on real data: 0.4531132102012634
# Accuracy on fake data: 0.5575507611036301
# Iteration:64
# Accuracy on real data: 0.40594274997711177
# Accuracy on fake data: 0.5669671505689621
# Iteration:65
# Accuracy on real data: 0.43085312843322754
# Accuracy on fake data: 0.5596419245004653
# Iteration:66
# Accuracy on real data: 0.43209043741226194
# Accuracy on fake data: 0.5670343279838562
# Iteration:67
# Accuracy on real data: 0.3979582548141479
# Accuracy on fake data: 0.5646327763795853
# Iteration:68
# Accuracy on real data: 0.36439972519874575
# Accuracy on fake data: 0.5682744264602662
# Iteration:69
# Accuracy on real data: 0.41913377642631533
# Accuracy on fake data: 0.5793652325868607
# Iteration:70
# Accuracy on real data: 0.412834620475769
# Accuracy on fake data: 0.5673799991607666
# Iteration:71
# Accuracy on real data: 0.3994418561458588
# Accuracy on fake data: 0.588217917084694
# Iteration:72
# Accuracy on real data: 0.3929145932197571
# Accuracy on fake data: 0.5673226147890091
# Iteration:73
# Accuracy on real data: 0.3699584543704987
# Accuracy on fake data: 0.5596706360578537
# Iteration:74
# Accuracy on real data: 0.33514609932899475
# Accuracy on fake data: 0.5576145559549331
# Iteration:75
# Accuracy on real data: 0.34811989068984983
# Accuracy on fake data: 0.5804200500249863
# Iteration:76
# Accuracy on real data: 0.35354635715484617
# Accuracy on fake data: 0.5850135892629623
# Iteration:77
# Accuracy on real data: 0.34150329828262327
# Accuracy on fake data: 0.5861879229545593
# Iteration:78
# Accuracy on real data: 0.32990626692771907
# Accuracy on fake data: 0.6030550122261047
# Iteration:79
# Accuracy on real data: 0.32919292449951176
# Accuracy on fake data: 0.6168312966823578
# Iteration:80
# Accuracy on real data: 0.32946849465370176
# Accuracy on fake data: 0.6276408851146698
# Iteration:81
# Accuracy on real data: 0.3367889165878296
# Accuracy on fake data: 0.6350555926561355
# Iteration:82
# Accuracy on real data: 0.341566389799118
# Accuracy on fake data: 0.6345545917749404
# Iteration:83
# Accuracy on real data: 0.3169834554195404
# Accuracy on fake data: 0.6588332504034042
# Iteration:84
# Accuracy on real data: 0.3248878180980682
# Accuracy on fake data: 0.6558065325021744
# Iteration:85
# Accuracy on real data: 0.3554598212242126
# Accuracy on fake data: 0.672522908449173
# Iteration:86
# Accuracy on real data: 0.3442168474197388
# Accuracy on fake data: 0.6630001872777939
# Iteration:87
# Accuracy on real data: 0.2962031245231629
# Accuracy on fake data: 0.6644754827022552
# Iteration:88
# Accuracy on real data: 0.368924331665039
# Accuracy on fake data: 0.6932538241147995
# Iteration:89
# Accuracy on real data: 0.28511584401130674
# Accuracy on fake data: 0.70411496758461
# Iteration:90
# Accuracy on real data: 0.2771796226501465
# Accuracy on fake data: 0.7078618884086609
# Iteration:91
# Accuracy on real data: 0.3453169226646423
# Accuracy on fake data: 0.709774187207222
# Iteration:92
# Accuracy on real data: 0.3321410477161407
# Accuracy on fake data: 0.6988488525152207
# Iteration:93
# Accuracy on real data: 0.2737430095672607
# Accuracy on fake data: 0.702674788236618
# Iteration:94
# Accuracy on real data: 0.2895653486251831
# Accuracy on fake data: 0.694784215092659
# Iteration:95
# Accuracy on real data: 0.26398739218711853
# Accuracy on fake data: 0.7096939414739609
# Iteration:96
# Accuracy on real data: 0.2915943920612335
# Accuracy on fake data: 0.7226687461137772
# Iteration:97
# Accuracy on real data: 0.2958529174327851
# Accuracy on fake data: 0.718901914358139
# Iteration:98
# Accuracy on real data: 0.2917381227016449
# Accuracy on fake data: 0.7264049142599106
# Iteration:99
# Accuracy on real data: 0.30049079060554507
# Accuracy on fake data: 0.7215888261795044
# Iteration [99/4000] - loss_d: -0.22337205708026886, loss_g: -0.26684486865997314, w_dist: 0.39994657039642334, grad_penalty: 0.17657451331615448
# Iteration:100
# Accuracy on real data: 0.30194152593612666
# Accuracy on fake data: 0.7302843034267426
# Iteration:101
# Accuracy on real data: 0.31379192471504214
# Accuracy on fake data: 0.7289469361305236
# Iteration:102
# Accuracy on real data: 0.28870421051979067
# Accuracy on fake data: 0.7373480871319771
# Iteration:103
# Accuracy on real data: 0.31462821960449217
# Accuracy on fake data: 0.7381345197558403
# Iteration:104
# Accuracy on real data: 0.3022659838199615
# Accuracy on fake data: 0.7390208542346954
# Iteration:105
# Accuracy on real data: 0.27923830151557927
# Accuracy on fake data: 0.752031822502613
# Iteration:106
# Accuracy on real data: 0.29770348668098445
# Accuracy on fake data: 0.7525389909744262
# Iteration:107
# Accuracy on real data: 0.2963789284229279
# Accuracy on fake data: 0.7614926367998123
# Iteration:108
# Accuracy on real data: 0.3055323660373688
# Accuracy on fake data: 0.7457653939723968
# Iteration:109
# Accuracy on real data: 0.28226607441902163
# Accuracy on fake data: 0.7522172570228577
# Iteration:110
# Accuracy on real data: 0.29403259158134465
# Accuracy on fake data: 0.7420336395502091
# Iteration:111
# Accuracy on real data: 0.25848216414451597
# Accuracy on fake data: 0.7637449622154235
# Iteration:112
# Accuracy on real data: 0.25824837088584895
# Accuracy on fake data: 0.7746410101652146
# Iteration:113
# Accuracy on real data: 0.296103173494339
# Accuracy on fake data: 0.7662305206060409
# Iteration:114
# Accuracy on real data: 0.3201415479183197
# Accuracy on fake data: 0.740843978524208
# Iteration:115
# Accuracy on real data: 0.26036863923072817
# Accuracy on fake data: 0.7416881293058395
# Iteration:116
# Accuracy on real data: 0.2768967092037201
# Accuracy on fake data: 0.7386494666337967
# Iteration:117
# Accuracy on real data: 0.2664120972156525
# Accuracy on fake data: 0.7555170238018036
# Iteration:118
# Accuracy on real data: 0.29880073070526125
# Accuracy on fake data: 0.7640675067901611
# Iteration:119
# Accuracy on real data: 0.2823229551315307
# Accuracy on fake data: 0.7628833755850792
# Iteration:120
# Accuracy on real data: 0.28848942518234255
# Accuracy on fake data: 0.761996565759182
# Iteration:121
# Accuracy on real data: 0.2737718999385834
# Accuracy on fake data: 0.7487405478954315
# Iteration:122
# Accuracy on real data: 0.2735525667667389
# Accuracy on fake data: 0.7548747733235359
# Iteration:123
# Accuracy on real data: 0.2814650416374207
# Accuracy on fake data: 0.7472105368971824
# Iteration:124
# Accuracy on real data: 0.2809451341629028
# Accuracy on fake data: 0.7558106362819672
# Iteration:125
# Accuracy on real data: 0.29824600815773006
# Accuracy on fake data: 0.7651249095797539
# Iteration:126
# Accuracy on real data: 0.2292908072471619
# Accuracy on fake data: 0.76742924451828
# Iteration:127
# Accuracy on real data: 0.27052457928657536
# Accuracy on fake data: 0.7847172766923904
# Iteration:128
# Accuracy on real data: 0.2629555284976959
# Accuracy on fake data: 0.7947527036070824
# Iteration:129
# Accuracy on real data: 0.286274117231369
# Accuracy on fake data: 0.7808651357889176
# Iteration:130
# Accuracy on real data: 0.2697719752788543
# Accuracy on fake data: 0.7661046981811523
# Iteration:131
# Accuracy on real data: 0.2797582924365998
# Accuracy on fake data: 0.7868116125464439
# Iteration:132
# Accuracy on real data: 0.24347198605537412
# Accuracy on fake data: 0.8055419534444809
# Iteration:133
# Accuracy on real data: 0.3007586240768433
# Accuracy on fake data: 0.7907678917050361
# Iteration:134
# Accuracy on real data: 0.27142786979675293
# Accuracy on fake data: 0.7731325596570968
# Iteration:135
# Accuracy on real data: 0.32385556697845463
# Accuracy on fake data: 0.7768994033336639
# Iteration:136
# Accuracy on real data: 0.26389287114143367
# Accuracy on fake data: 0.7857917189598084
# Iteration:137
# Accuracy on real data: 0.26861724853515623
# Accuracy on fake data: 0.7810144618153572
# Iteration:138
# Accuracy on real data: 0.2598754405975342
# Accuracy on fake data: 0.7836708754301072
# Iteration:139
# Accuracy on real data: 0.27038205862045284
# Accuracy on fake data: 0.8107412919402123
# Iteration:140
# Accuracy on real data: 0.2369224727153778
# Accuracy on fake data: 0.8120958283543587
# Iteration:141
# Accuracy on real data: 0.2349147439002991
# Accuracy on fake data: 0.7869549721479416
# Iteration:142
# Accuracy on real data: 0.21382837891578677
# Accuracy on fake data: 0.7865259185433388
# Iteration:143
# Accuracy on real data: 0.27224506139755245
# Accuracy on fake data: 0.7931351661682129
# Iteration:144
# Accuracy on real data: 0.25661143064498904
# Accuracy on fake data: 0.7937686070799828
# Iteration:145
# Accuracy on real data: 0.25747414827346804
# Accuracy on fake data: 0.8036886706948281
# Iteration:146
# Accuracy on real data: 0.25911509394645693
# Accuracy on fake data: 0.8031951949000359
# Iteration:147
# Accuracy on real data: 0.27263937592506404
# Accuracy on fake data: 0.8246206849813461
# Iteration:148
# Accuracy on real data: 0.2387243032455444
# Accuracy on fake data: 0.8215939164161682
# Iteration:149
# Accuracy on real data: 0.21627331972122188
# Accuracy on fake data: 0.8142533406615258
# Iteration:150
# Accuracy on real data: 0.24452936053276064
# Accuracy on fake data: 0.7967686548829078
# Iteration:151
# Accuracy on real data: 0.2684305846691132
# Accuracy on fake data: 0.8157910659909249
# Iteration:152
# Accuracy on real data: 0.29191990494728093
# Accuracy on fake data: 0.7997887507081032
# Iteration:153
# Accuracy on real data: 0.2656921803951263
# Accuracy on fake data: 0.8009689316153527
# Iteration:154
# Accuracy on real data: 0.2513722360134125
# Accuracy on fake data: 0.7982304140925407
# Iteration:155
# Accuracy on real data: 0.20619257092475896
# Accuracy on fake data: 0.8078544810414314
# Iteration:156
# Accuracy on real data: 0.23364599943161013
# Accuracy on fake data: 0.8144791722297668
# Iteration:157
# Accuracy on real data: 0.2511639356613159
# Accuracy on fake data: 0.8058705255389214
# Iteration:158
# Accuracy on real data: 0.22042218446731565
# Accuracy on fake data: 0.8079096138477325
# Iteration:159
# Accuracy on real data: 0.25523840188980107
# Accuracy on fake data: 0.8268088936805725
# Iteration:160
# Accuracy on real data: 0.18464244604110713
# Accuracy on fake data: 0.8333051592111588
# Iteration:161
# Accuracy on real data: 0.17242473959922788
# Accuracy on fake data: 0.8329248070716858
# Iteration:162
# Accuracy on real data: 0.2131197154521942
# Accuracy on fake data: 0.8330414742231369
# Iteration:163
# Accuracy on real data: 0.21737566590309143
# Accuracy on fake data: 0.8194478467106819
# Iteration:164
# Accuracy on real data: 0.2185903668403626
# Accuracy on fake data: 0.8328314557671547
# Iteration:165
# Accuracy on real data: 0.2174452841281891
# Accuracy on fake data: 0.8362573981285095
# Iteration:166
# Accuracy on real data: 0.2307155311107636
# Accuracy on fake data: 0.8316917404532432
# Iteration:167
# Accuracy on real data: 0.20907079577445986
# Accuracy on fake data: 0.8032427683472634
# Iteration:168
# Accuracy on real data: 0.18611499071121218
# Accuracy on fake data: 0.825991939008236
# Iteration:169
# Accuracy on real data: 0.17123332023620608
# Accuracy on fake data: 0.8227287560701371
# Iteration:170
# Accuracy on real data: 0.16631307005882268
# Accuracy on fake data: 0.8265564024448395
# Iteration:171
# Accuracy on real data: 0.18963803052902217
# Accuracy on fake data: 0.824850258231163
# Iteration:172
# Accuracy on real data: 0.22266281247138975
# Accuracy on fake data: 0.7885060459375381
# Iteration:173
# Accuracy on real data: 0.17880973815917967
# Accuracy on fake data: 0.7787403017282486
# Iteration:174
# Accuracy on real data: 0.15217090249061582
# Accuracy on fake data: 0.7871763974428176
# Iteration:175
# Accuracy on real data: 0.16888431310653684
# Accuracy on fake data: 0.8020098447799683
# Iteration:176
# Accuracy on real data: 0.15099202394485478
# Accuracy on fake data: 0.8232801422476769
# Iteration:177
# Accuracy on real data: 0.18536633253097534
# Accuracy on fake data: 0.8367830961942673
# Iteration:178
# Accuracy on real data: 0.17095711231231692
# Accuracy on fake data: 0.8237646847963334
# Iteration:179
# Accuracy on real data: 0.1696244597434997
# Accuracy on fake data: 0.824038664996624
# Iteration:180
# Accuracy on real data: 0.16499238014221196
# Accuracy on fake data: 0.799212583899498
# Iteration:181
# Accuracy on real data: 0.20455546975135808
# Accuracy on fake data: 0.7951278194785119
# Iteration:182
# Accuracy on real data: 0.19341216683387752
# Accuracy on fake data: 0.7914951786398887
# Iteration:183
# Accuracy on real data: 0.16530302762985227
# Accuracy on fake data: 0.817120935022831
# Iteration:184
# Accuracy on real data: 0.2031029880046844
# Accuracy on fake data: 0.8146112367510796
# Iteration:185
# Accuracy on real data: 0.14110195040702822
# Accuracy on fake data: 0.8169563040137291
# Iteration:186
# Accuracy on real data: 0.14160344004631042
# Accuracy on fake data: 0.8235935166478157
# Iteration:187
# Accuracy on real data: 0.13743419051170347
# Accuracy on fake data: 0.8286977842450142
# Iteration:188
# Accuracy on real data: 0.1751807391643524
# Accuracy on fake data: 0.824849297106266
# Iteration:189
# Accuracy on real data: 0.16573775410652158
# Accuracy on fake data: 0.8114472329616547
# Iteration:190
# Accuracy on real data: 0.14727848768234253
# Accuracy on fake data: 0.8299291431903839
# Iteration:191
# Accuracy on real data: 0.14726353287696836
# Accuracy on fake data: 0.8539020463824272
# Iteration:192
# Accuracy on real data: 0.15617031455039976
# Accuracy on fake data: 0.835984668135643
# Iteration:193
# Accuracy on real data: 0.1494055151939392
# Accuracy on fake data: 0.8347887426614762
# Iteration:194
# Accuracy on real data: 0.20314267873764036
# Accuracy on fake data: 0.8265842005610466
# Iteration:195
# Accuracy on real data: 0.1468667566776276
# Accuracy on fake data: 0.8182251855731011
# Iteration:196
# Accuracy on real data: 0.15535771250724795
# Accuracy on fake data: 0.8265161499381065
# Iteration:197
# Accuracy on real data: 0.1885523915290832
# Accuracy on fake data: 0.8091444045305252
# Iteration:198
# Accuracy on real data: 0.11673164963722227
# Accuracy on fake data: 0.8179163992404938
# Iteration:199
# Accuracy on real data: 0.12429555654525759
# Accuracy on fake data: 0.8430839404463768
# Iteration [199/4000] - loss_d: -0.5232976675033569, loss_g: -0.15404058992862701, w_dist: 0.7140721082687378, grad_penalty: 0.19077444076538086
# Iteration:200
# Accuracy on real data: 0.12476950287818911
# Accuracy on fake data: 0.8370577603578567
# Iteration:201
# Accuracy on real data: 0.1300603568553924
# Accuracy on fake data: 0.8296860203146934
# Iteration:202
# Accuracy on real data: 0.11960474848747249
# Accuracy on fake data: 0.8511029735207558
# Iteration:203
# Accuracy on real data: 0.11647856831550596
# Accuracy on fake data: 0.8398927211761474
# Iteration:204
# Accuracy on real data: 0.12819290161132812
# Accuracy on fake data: 0.8280424743890762
# Iteration:205
# Accuracy on real data: 0.12363824248313904
# Accuracy on fake data: 0.8243690252304077
# Iteration:206
# Accuracy on real data: 0.10059652328491209
# Accuracy on fake data: 0.8258750110864639
# Iteration:207
# Accuracy on real data: 0.12924730181694033
# Accuracy on fake data: 0.8341675609350204
# Iteration:208
# Accuracy on real data: 0.10709720849990845
# Accuracy on fake data: 0.8394386649131775
# Iteration:209
# Accuracy on real data: 0.18280968070030212
# Accuracy on fake data: 0.8367289379239082
# Iteration:210
# Accuracy on real data: 0.16107659935951235
# Accuracy on fake data: 0.8294958934187889
# Iteration:211
# Accuracy on real data: 0.12410140633583067
# Accuracy on fake data: 0.8233120188117027
# Iteration:212
# Accuracy on real data: 0.1477292358875275
# Accuracy on fake data: 0.8261604562401772
# Iteration:213
# Accuracy on real data: 0.10699505209922788
# Accuracy on fake data: 0.8298780441284179
# Iteration:214
# Accuracy on real data: 0.15061029195785525
# Accuracy on fake data: 0.8220195874571801
# Iteration:215
# Accuracy on real data: 0.11965933442115784
# Accuracy on fake data: 0.8225944757461547
# Iteration:216
# Accuracy on real data: 0.09488427042961123
# Accuracy on fake data: 0.8274576455354691
# Iteration:217
# Accuracy on real data: 0.1655961573123932
# Accuracy on fake data: 0.8204022765159606
# Iteration:218
# Accuracy on real data: 0.13479106426239018
# Accuracy on fake data: 0.8110245674848556
# Iteration:219
# Accuracy on real data: 0.09243605732917781
# Accuracy on fake data: 0.8189330041408539
# Iteration:220
# Accuracy on real data: 0.1562665641307831
# Accuracy on fake data: 0.8119853511452675
# Iteration:221
# Accuracy on real data: 0.13073842525482182
# Accuracy on fake data: 0.8005915567278862
# Iteration:222
# Accuracy on real data: 0.11995322108268736
# Accuracy on fake data: 0.8063081860542297
# Iteration:223
# Accuracy on real data: 0.126679801940918
# Accuracy on fake data: 0.8049310579895973
# Iteration:224
# Accuracy on real data: 0.13515272736549377
# Accuracy on fake data: 0.8161883264780044
# Iteration:225
# Accuracy on real data: 0.1081876933574677
# Accuracy on fake data: 0.8323712334036827
# Iteration:226
# Accuracy on real data: 0.13663640022277834
# Accuracy on fake data: 0.8147978246212005
# Iteration:227
# Accuracy on real data: 0.12501180171966553
# Accuracy on fake data: 0.8038124203681946
# Iteration:228
# Accuracy on real data: 0.15056991577148438
# Accuracy on fake data: 0.812855276465416
# Iteration:229
# Accuracy on real data: 0.14105039834976196
# Accuracy on fake data: 0.8138694375753402
# Iteration:230
# Accuracy on real data: 0.11572268009185793
# Accuracy on fake data: 0.8387322366237641
# Iteration:231
# Accuracy on real data: 0.1255251288414001
# Accuracy on fake data: 0.8199209168553352
# Iteration:232
# Accuracy on real data: 0.13034779429435728
# Accuracy on fake data: 0.8082385882735252
# Iteration:233
# Accuracy on real data: 0.10683031082153316
# Accuracy on fake data: 0.8176265075802803
# Iteration:234
# Accuracy on real data: 0.17546219825744624
# Accuracy on fake data: 0.8065370783209801
# Iteration:235
# Accuracy on real data: 0.13579791188240053
# Accuracy on fake data: 0.816281045973301
# Iteration:236
# Accuracy on real data: 0.16840183138847353
# Accuracy on fake data: 0.807602071762085
# Iteration:237
# Accuracy on real data: 0.11726287603378294
# Accuracy on fake data: 0.8268076092004776
# Iteration:238
# Accuracy on real data: 0.12172073125839233
# Accuracy on fake data: 0.8267276108264923
# Iteration:239
# Accuracy on real data: 0.09536499977111812
# Accuracy on fake data: 0.8244574263691902
# Iteration:240
# Accuracy on real data: 0.10308966040611267
# Accuracy on fake data: 0.8429733410477638
# Iteration:241
# Accuracy on real data: 0.12185488343238826
# Accuracy on fake data: 0.8147044748067855
# Iteration:242
# Accuracy on real data: 0.08799311518669128
# Accuracy on fake data: 0.8302565693855286
# Iteration:243
# Accuracy on real data: 0.11163580417633057
# Accuracy on fake data: 0.8237339675426483
# Iteration:244
# Accuracy on real data: 0.10505744218826296
# Accuracy on fake data: 0.8420545950531959
# Iteration:245
# Accuracy on real data: 0.0881281971931458
# Accuracy on fake data: 0.8263973623514176
# Iteration:246
# Accuracy on real data: 0.12255546450614929
# Accuracy on fake data: 0.8327244773507119
# Iteration:247
# Accuracy on real data: 0.12916736602783208
# Accuracy on fake data: 0.8140667587518692
# Iteration:248
# Accuracy on real data: 0.12435544133186338
# Accuracy on fake data: 0.8060271263122558
# Iteration:249
# Accuracy on real data: 0.10999119877815244
# Accuracy on fake data: 0.811625574529171
# Iteration:250
# Accuracy on real data: 0.11034489274024961
# Accuracy on fake data: 0.81710215061903
# Iteration:251
# Accuracy on real data: 0.08305277824401858
# Accuracy on fake data: 0.8301932409405708
# Iteration:252
# Accuracy on real data: 0.08329490423202512
# Accuracy on fake data: 0.8337486639618874
# Iteration:253
# Accuracy on real data: 0.14213885068893428
# Accuracy on fake data: 0.8093502581119537
# Iteration:254
# Accuracy on real data: 0.12005769014358525
# Accuracy on fake data: 0.8086419939994812
# Iteration:255
# Accuracy on real data: 0.09525640606880192
# Accuracy on fake data: 0.794633561372757
# Iteration:256
# Accuracy on real data: 0.11779346466064455
# Accuracy on fake data: 0.8018734127283096
# Iteration:257
# Accuracy on real data: 0.05634413361549373
# Accuracy on fake data: 0.8258860662579537
# Iteration:258
# Accuracy on real data: 0.0802555322647095
# Accuracy on fake data: 0.8360213741660119
# Iteration:259
# Accuracy on real data: 0.1066105186939239
# Accuracy on fake data: 0.8102127447724342
# Iteration:260
# Accuracy on real data: 0.13265081048011784
# Accuracy on fake data: 0.7981629326939583
# Iteration:261
# Accuracy on real data: 0.09648853540420532
# Accuracy on fake data: 0.8172484025359154
# Iteration:262
# Accuracy on real data: 0.11193939447402956
# Accuracy on fake data: 0.811475756764412
# Iteration:263
# Accuracy on real data: 0.113724273443222
# Accuracy on fake data: 0.8120942458510398
# Iteration:264
# Accuracy on real data: 0.09776879549026485
# Accuracy on fake data: 0.8082565709948539
# Iteration:265
# Accuracy on real data: 0.11884970664978023
# Accuracy on fake data: 0.8137677416205407
# Iteration:266
# Accuracy on real data: 0.12386517524719243
# Accuracy on fake data: 0.8121408179402352
# Iteration:267
# Accuracy on real data: 0.11497789025306704
# Accuracy on fake data: 0.8164500176906586
# Iteration:268
# Accuracy on real data: 0.10066685676574705
# Accuracy on fake data: 0.8134492486715317
# Iteration:269
# Accuracy on real data: 0.10764495730400081
# Accuracy on fake data: 0.8113985329866409
# Iteration:270
# Accuracy on real data: 0.10591925382614131
# Accuracy on fake data: 0.7963533043861389
# Iteration:271
# Accuracy on real data: 0.10669589042663574
# Accuracy on fake data: 0.8097372025251388
# Iteration:272
# Accuracy on real data: 0.10343243479728703
# Accuracy on fake data: 0.7829817116260529
# Iteration:273
# Accuracy on real data: 0.05733160972595219
# Accuracy on fake data: 0.7725680440664291
# Iteration:274
# Accuracy on real data: 0.1309740483760834
# Accuracy on fake data: 0.7482983589172363
# Iteration:275
# Accuracy on real data: 0.15060439109802248
# Accuracy on fake data: 0.7506039544939995
# Iteration:276
# Accuracy on real data: 0.117523866891861
# Accuracy on fake data: 0.748253321647644
# Iteration:277
# Accuracy on real data: 0.08676017522811885
# Accuracy on fake data: 0.7422908037900925
# Iteration:278
# Accuracy on real data: 0.040407496690750166
# Accuracy on fake data: 0.7509748935699463
# Iteration:279
# Accuracy on real data: 0.10658932924270625
# Accuracy on fake data: 0.7377291321754456
# Iteration:280
# Accuracy on real data: 0.08887994289398193
# Accuracy on fake data: 0.7293169036507606
# Iteration:281
# Accuracy on real data: 0.05365098118782041
# Accuracy on fake data: 0.7096375614404679
# Iteration:282
# Accuracy on real data: 0.04253339171409609
# Accuracy on fake data: 0.7008778154850006
# Iteration:283
# Accuracy on real data: 0.046530842781066895
# Accuracy on fake data: 0.7090150862932205
# Iteration:284
# Accuracy on real data: 0.03160845041275029
# Accuracy on fake data: 0.6821390748023987
# Iteration:285
# Accuracy on real data: 0.024486637115478493
# Accuracy on fake data: 0.7727654501795769
# Iteration:286
# Accuracy on real data: 9.598135948185593e-05
# Accuracy on fake data: 0.7838958650827408
# Iteration:287
# Accuracy on real data: 0.000788921117782615
# Accuracy on fake data: 0.6647898852825165
# Iteration:288
# Accuracy on real data: 0.016543447971343994
# Accuracy on fake data: 0.746402594447136
# Iteration:289
# Accuracy on real data: 0.08720838427543642
# Accuracy on fake data: 0.7689012303948403
# Iteration:290
# Accuracy on real data: 0.06373555660247798
# Accuracy on fake data: 0.7197515740990639
# Iteration:291
# Accuracy on real data: 0.09997348785400395
# Accuracy on fake data: 0.6469274044036866
# Iteration:292
# Accuracy on real data: 0.10944570302963252
# Accuracy on fake data: 0.6444606482982635
# Iteration:293
# Accuracy on real data: 0.11254052519798274
# Accuracy on fake data: 0.7109472066164017
# Iteration:294
# Accuracy on real data: 0.10685010552406315
# Accuracy on fake data: 0.741138382256031
# Iteration:295
# Accuracy on real data: 0.026603400707244873
# Accuracy on fake data: 0.7675040498375892
# Iteration:296
# Accuracy on real data: 0.04201664924621584
# Accuracy on fake data: 0.7100774466991424
# Iteration:297
# Accuracy on real data: 0.04729517698287966
# Accuracy on fake data: 0.6812745690345764
# Iteration:298
# Accuracy on real data: 0.07852186560630803
# Accuracy on fake data: 0.6721671789884567
# Iteration:299
# Accuracy on real data: 0.0397485136985779
# Accuracy on fake data: 0.7490107491612434
# Iteration [299/4000] - loss_d: 1.3342571258544922, loss_g: -0.2525467574596405, w_dist: 0.6925901770591736, grad_penalty: 2.0268473625183105
# Iteration:300
# Accuracy on real data: 0.09095988869667049
# Accuracy on fake data: 0.7592153266072273
# Iteration:301
# Accuracy on real data: 0.08567716479301457
# Accuracy on fake data: 0.7166107684373856
# Iteration:302
# Accuracy on real data: 0.10469130277633665
# Accuracy on fake data: 0.6813551098108291
# Iteration:303
# Accuracy on real data: 0.04141038060188296
# Accuracy on fake data: 0.7672423183917999
# Iteration:304
# Accuracy on real data: 0.06942272782325742
# Accuracy on fake data: 0.7653191581368446
# Iteration:305
# Accuracy on real data: 0.10644508600234981
# Accuracy on fake data: 0.7562635004520416
# Iteration:306
# Accuracy on real data: 0.06889954209327698
# Accuracy on fake data: 0.7087659716606141
# Iteration:307
# Accuracy on real data: 0.13994212150573726
# Accuracy on fake data: 0.6764199167490006
# Iteration:308
# Accuracy on real data: 0.1068367481231689
# Accuracy on fake data: 0.6897389560937881
# Iteration:309
# Accuracy on real data: 0.05904146432876589
# Accuracy on fake data: 0.679676279425621
# Iteration:310
# Accuracy on real data: 0.0733424842357635
# Accuracy on fake data: 0.6514659643173217
# Iteration:311
# Accuracy on real data: 0.199657016992569
# Accuracy on fake data: 0.6460798412561417
# Iteration:312
# Accuracy on real data: 0.12735014557838442
# Accuracy on fake data: 0.6938001543283463
# Iteration:313
# Accuracy on real data: 0.08076431751251223
# Accuracy on fake data: 0.6730385214090348
# Iteration:314
# Accuracy on real data: 0.04408755898475647
# Accuracy on fake data: 0.6778461694717407
# Iteration:315
# Accuracy on real data: 0.11584616303443906
# Accuracy on fake data: 0.6549297213554383
# Iteration:316
# Accuracy on real data: 0.07772188186645512
# Accuracy on fake data: 0.6710367530584336
# Iteration:317
# Accuracy on real data: 0.1095728874206543
# Accuracy on fake data: 0.6860011667013168
# Iteration:318
# Accuracy on real data: 0.06449100971221922
# Accuracy on fake data: 0.6881488978862762
# Iteration:319
# Accuracy on real data: 0.05653255581855776
# Accuracy on fake data: 0.6606551319360733
# Iteration:320
# Accuracy on real data: 0.041117978096008256
# Accuracy on fake data: 0.6735764920711518
# Iteration:321
# Accuracy on real data: 0.09154193401336674
# Accuracy on fake data: 0.689254853129387
# Iteration:322
# Accuracy on real data: 0.11269724369049072
# Accuracy on fake data: 0.6984793990850449
# Iteration:323
# Accuracy on real data: 0.12348658442497251
# Accuracy on fake data: 0.7197225779294968
# Iteration:324
# Accuracy on real data: 0.09051311016082764
# Accuracy on fake data: 0.6913204610347747
# Iteration:325
# Accuracy on real data: 0.08249537348747249
# Accuracy on fake data: 0.6949392974376678
# Iteration:326
# Accuracy on real data: 0.10226347446441653
# Accuracy on fake data: 0.7116129547357559
# Iteration:327
# Accuracy on real data: 0.06209633350372312
# Accuracy on fake data: 0.7166418761014939
# Iteration:328
# Accuracy on real data: 0.09299384951591494
# Accuracy on fake data: 0.6904953926801681
# Iteration:329
# Accuracy on real data: 0.09491054415702815
# Accuracy on fake data: 0.682363310456276
# Iteration:330
# Accuracy on real data: 0.07504591345787048
# Accuracy on fake data: 0.6869341433048248
# Iteration:331
# Accuracy on real data: 0.07856739759445186
# Accuracy on fake data: 0.6960982978343964
# Iteration:332
# Accuracy on real data: 0.11334682703018184
# Accuracy on fake data: 0.735318922996521
# Iteration:333
# Accuracy on real data: 0.09910585880279543
# Accuracy on fake data: 0.7443593949079513
# Iteration:334
# Accuracy on real data: 0.1385406792163849
# Accuracy on fake data: 0.7040709584951401
# Iteration:335
# Accuracy on real data: 0.1191447794437408
# Accuracy on fake data: 0.6970458388328552
# Iteration:336
# Accuracy on real data: 0.10437818169593815
# Accuracy on fake data: 0.7074226617813111
# Iteration:337
# Accuracy on real data: 0.0939967930316925
# Accuracy on fake data: 0.7061953097581863
# Iteration:338
# Accuracy on real data: 0.09025870561599736
# Accuracy on fake data: 0.6969065874814987
# Iteration:339
# Accuracy on real data: 0.1042802214622498
# Accuracy on fake data: 0.7023772895336151
# Iteration:340
# Accuracy on real data: 0.09630995988845825
# Accuracy on fake data: 0.7044198721647262
# Iteration:341
# Accuracy on real data: 0.09997920989990239
# Accuracy on fake data: 0.7080756276845932
# Iteration:342
# Accuracy on real data: 0.058722454309463545
# Accuracy on fake data: 0.7025965332984925
# Iteration:343
# Accuracy on real data: 0.05292437076568601
# Accuracy on fake data: 0.7246556550264358
# Iteration:344
# Accuracy on real data: 0.009385776519775346
# Accuracy on fake data: 0.7080887347459793
# Iteration:345
# Accuracy on real data: 0.08952422738075261
# Accuracy on fake data: 0.7059964925050736
# Iteration:346
# Accuracy on real data: 0.10679997205734248
# Accuracy on fake data: 0.7156937479972839
# Iteration:347
# Accuracy on real data: 0.07136988639831543
# Accuracy on fake data: 0.700657045841217
# Iteration:348
# Accuracy on real data: 0.09576743245124819
# Accuracy on fake data: 0.6961681455373764
# Iteration:349
# Accuracy on real data: 0.07317978739738462
# Accuracy on fake data: 0.7039298772811889
# Iteration:350
# Accuracy on real data: 0.08658185601234436
# Accuracy on fake data: 0.7080016374588013
# Iteration:351
# Accuracy on real data: 0.13854515552520752
# Accuracy on fake data: 0.7052661806344986
# Iteration:352
# Accuracy on real data: 0.06627606153488164
# Accuracy on fake data: 0.7026341110467911
# Iteration:353
# Accuracy on real data: 0.0991524398326874
# Accuracy on fake data: 0.7275545090436936
# Iteration:354
# Accuracy on real data: 0.07539501190185549
# Accuracy on fake data: 0.7603841364383698
# Iteration:355
# Accuracy on real data: 0.0889930188655853
# Accuracy on fake data: 0.7099223554134368
# Iteration:356
# Accuracy on real data: 0.10476052165031435
# Accuracy on fake data: 0.7091616034507752
# Iteration:357
# Accuracy on real data: 0.1430945217609405
# Accuracy on fake data: 0.70707688331604
# Iteration:358
# Accuracy on real data: 0.1288534283638001
# Accuracy on fake data: 0.7305627495050431
# Iteration:359
# Accuracy on real data: 0.11443972587585449
# Accuracy on fake data: 0.7246468484401702
# Iteration:360
# Accuracy on real data: 0.10862429141998287
# Accuracy on fake data: 0.738005243241787
# Iteration:361
# Accuracy on real data: 0.11462475657463078
# Accuracy on fake data: 0.7050756931304931
# Iteration:362
# Accuracy on real data: 0.07705078124999998
# Accuracy on fake data: 0.7159029692411423
# Iteration:363
# Accuracy on real data: 0.07270449995994566
# Accuracy on fake data: 0.7223030090332031
# Iteration:364
# Accuracy on real data: 0.06637227535247803
# Accuracy on fake data: 0.718827286362648
# Iteration:365
# Accuracy on real data: 0.03230385780334477
# Accuracy on fake data: 0.6847678482532501
# Iteration:366
# Accuracy on real data: 0.03489666581153872
# Accuracy on fake data: 0.6920236378908158
# Iteration:367
# Accuracy on real data: 0.0894092321395874
# Accuracy on fake data: 0.700510847568512
# Iteration:368
# Accuracy on real data: 0.04700139760971067
# Accuracy on fake data: 0.7138458341360092
# Iteration:369
# Accuracy on real data: 0.045199519395828225
# Accuracy on fake data: 0.895745687559247
# Iteration:370
# Accuracy on real data: 0.010276013612747215
# Accuracy on fake data: 0.9652115107508489
# Iteration:371
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.9999966323748388
# Iteration:372
# Accuracy on real data: 0.07812497615814207
# Accuracy on fake data: 0.999999920267003
# Iteration:373
# Accuracy on real data: 0.046875
# Accuracy on fake data: 0.9999986390684917
# Iteration:374
# Accuracy on real data: 0.039833384752273604
# Accuracy on fake data: 0.9997127850774796
# Iteration:375
# Accuracy on real data: 0.01910743713378904
# Accuracy on fake data: 0.9486216237768531
# Iteration:376
# Accuracy on real data: 0.015625
# Accuracy on fake data: 0.8674356743693352
# Iteration:377
# Accuracy on real data: 0.046869462728500344
# Accuracy on fake data: 0.8378908939659595
# Iteration:378
# Accuracy on real data: 0.015625
# Accuracy on fake data: 0.827055162191391
# Iteration:379
# Accuracy on real data: 0.029301851987838745
# Accuracy on fake data: 0.9649673566857928
# Iteration:380
# Accuracy on real data: 0.046875
# Accuracy on fake data: 0.9999662772923416
# Iteration:381
# Accuracy on real data: 0.033640813827514604
# Accuracy on fake data: 0.9999996719366702
# Iteration:382
# Accuracy on real data: 0.0625
# Accuracy on fake data: 0.999999948289874
# Iteration:383
# Accuracy on real data: 0.06239913702011113
# Accuracy on fake data: 0.9999999978693879
# Iteration:384
# Accuracy on real data: 0.046875
# Accuracy on fake data: 0.999999999757541
# Iteration:385
# Accuracy on real data: 0.034886729717254594
# Accuracy on fake data: 0.9999998777454467
# Iteration:386
# Accuracy on real data: 0.015625
# Accuracy on fake data: 0.9982663976910047
# Iteration:387
# Accuracy on real data: 0.04687374234199526
# Accuracy on fake data: 0.9887463756764191
# Iteration:388
# Accuracy on real data: 0.03126023411750789
# Accuracy on fake data: 0.9939058448246214
# Iteration:389
# Accuracy on real data: 0.03119788765907283
# Accuracy on fake data: 0.9932485964382067
# Iteration:390
# Accuracy on real data: 0.013826805353164717
# Accuracy on fake data: 0.9625204719603062
# Iteration:391
# Accuracy on real data: 0.044204157590866044
# Accuracy on fake data: 0.8872686617076397
# Iteration:392
# Accuracy on real data: 0.15442405939102177
# Accuracy on fake data: 0.8220952823758125
# Iteration:393
# Accuracy on real data: 0.19021525979042053
# Accuracy on fake data: 0.7988253340125084
# Iteration:394
# Accuracy on real data: 0.20423671007156374
# Accuracy on fake data: 0.7839977607131005
# Iteration:395
# Accuracy on real data: 0.246235316991806
# Accuracy on fake data: 0.7543844506144524
# Iteration:396
# Accuracy on real data: 0.2272629022598267
# Accuracy on fake data: 0.7682309791445732
# Iteration:397
# Accuracy on real data: 0.2380039513111114
# Accuracy on fake data: 0.7601172253489494
# Iteration:398
# Accuracy on real data: 0.20907100439071657
# Accuracy on fake data: 0.765099772810936
# Iteration:399
# Accuracy on real data: 0.19322744011878967
# Accuracy on fake data: 0.7549149319529533
# Iteration [399/4000] - loss_d: -0.2559574544429779, loss_g: -0.254990816116333, w_dist: 0.5359194278717041, grad_penalty: 0.2799619734287262
# Iteration:400
# Accuracy on real data: 0.1806236326694488
# Accuracy on fake data: 0.7356376737356186
# Iteration:401
# Accuracy on real data: 0.19525578022003176
# Accuracy on fake data: 0.7167085647583008
# Iteration:402
# Accuracy on real data: 0.16771420240402224
# Accuracy on fake data: 0.7136001259088516
# Iteration:403
# Accuracy on real data: 0.15305357575416567
# Accuracy on fake data: 0.7043410450220108
# Iteration:404
# Accuracy on real data: 0.16743735671043392
# Accuracy on fake data: 0.6980131685733795
# Iteration:405
# Accuracy on real data: 0.1522569835186005
# Accuracy on fake data: 0.7002101570367814
# Iteration:406
# Accuracy on real data: 0.15763508081436162
# Accuracy on fake data: 0.696074116230011
# Iteration:407
# Accuracy on real data: 0.15420333743095394
# ...
# Iteration:46182
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46183
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46184
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46185
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46186
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46187
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46188
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46189
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46190
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46191
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46192
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46193
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46194
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46195
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46196
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46197
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46198
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46199
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration [46199/4000] - loss_d: 10.0, loss_g: -1.0, w_dist: 0.0, grad_penalty: 10.0
# Iteration:46200
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46201
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46202
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46203
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46204
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46205
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46206
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46207
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46208
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46209
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46210
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46211
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46212
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46213
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46214
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46215
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46216
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46217
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46218
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46219
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46220
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46221
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46222
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46223
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46224
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46225
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46226
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46227
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46228
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46229
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46230
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46231
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46232
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46233
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46234
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46235
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46236
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46237
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46238
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46239
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46240
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46241
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46242
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46243
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46244
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46245
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46246
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46247
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46248
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46249
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46250
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46251
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46252
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46253
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46254
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46255
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46256
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46257
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46258
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46259
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46260
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46261
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46262
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46263
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46264
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46265
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46266
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46267
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46268
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46269
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46270
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46271
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46272
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46273
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46274
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46275
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46276
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46277
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46278
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46279
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46280
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46281
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46282
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46283
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46284
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46285
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46286
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46287
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46288
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46289
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46290
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46291
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46292
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46293
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46294
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46295
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46296
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46297
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46298
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46299
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration [46299/4000] - loss_d: 10.0, loss_g: -1.0, w_dist: 0.0, grad_penalty: 10.0
# /homes/gws/sidlak/miniconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:168: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
# Iteration:46300
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46301
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46302
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46303
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46304
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46305
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46306
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46307
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46308
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46309
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46310
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46311
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46312
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46313
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46314
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46315
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46316
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46317
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46318
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46319
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46320
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46321
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46322
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46323
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46324
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46325
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46326
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46327
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46328
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46329
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46330
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46331
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46332
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46333
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46334
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46335
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46336
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46337
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46338
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46339
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46340
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46341
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46342
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46343
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46344
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46345
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46346
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46347
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46348
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46349
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46350
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46351
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46352
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46353
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46354
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46355
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46356
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46357
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46358
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46359
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46360
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46361
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46362
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46363
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46364
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46365
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46366
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46367
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46368
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46369
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46370
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46371
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46372
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46373
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46374
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46375
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46376
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46377
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46378
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46379
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46380
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46381
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46382
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46383
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46384
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46385
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46386
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46387
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46388
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46389
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46390
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46391
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46392
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46393
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46394
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46395
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46396
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46397
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46398
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46399
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration [46399/4000] - loss_d: 10.0, loss_g: -1.0, w_dist: 0.0, grad_penalty: 10.0
# Iteration:46400
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46401
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46402
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46403
# Accuracy on real data: 0.0
# Accuracy on fake data: 0.0
# Iteration:46404
